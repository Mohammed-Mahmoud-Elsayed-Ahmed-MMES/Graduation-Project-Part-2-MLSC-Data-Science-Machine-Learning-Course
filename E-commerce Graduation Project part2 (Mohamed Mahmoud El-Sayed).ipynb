# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
file_path = 'D:\Telegram Downloads\Cources\MLSC Data Science & Machine Learning Course\Graduation Project Part#2\E-commerce_data.xlsx'

df_sheets = pd.read_excel(file_path, sheet_name=None)

s1 = pd.read_excel(file_path, sheet_name='customers')

s2 = pd.read_excel(file_path, sheet_name='genders')

s3 = pd.read_excel(file_path, sheet_name='cities')

s4 = pd.read_excel(file_path, sheet_name='transactions')

s5 = pd.read_excel(file_path, sheet_name='branches')

s6 = pd.read_excel(file_path, sheet_name='merchants')

# %%
s1_2_3 = s1.merge(s2, how='left', on='gender_id') \
            .merge(s3, how='left', on='city_id')
s1_2_3
# Out:
#      customer_id  join_date  city_id  gender_id gender_name  \
# 0            1.0 2022-01-08      7.0        1.0        Male
# 1            2.0 2023-05-02     20.0        2.0      Female
# 2            3.0 2023-05-14     15.0        1.0        Male
# 3            4.0 2022-11-25     11.0        2.0      Female
# 4            5.0 2023-04-26      8.0        1.0        Male
# ..           ...        ...      ...        ...         ...
# 995        996.0 2022-10-28      3.0        1.0        Male
# 996        997.0 2022-07-07     20.0        2.0      Female
# 997        998.0 2024-03-09     11.0        2.0      Female
# 998        999.0 2022-07-16      6.0        1.0        Male
# 999       1000.0 2024-04-08      2.0        2.0      Female
#
#                city_name
# 0               Mansoura
# 1                  Sohag
# 2                  Aswan
# 3               Ismailia
# 4    El-Mahalla El-Kubra
# ..                   ...
# 995                 Giza
# 996                Sohag
# 997             Ismailia
# 998                 Suez
# 999           Alexandria
#
# [1000 rows x 6 columns]

# %%
s5_6 = s5.merge(s6, how='left', on='merchant_id')
s5_6
# Out:
#    branch_id  merchant_id                   merchant_name
# 0        1.0         11.0     Smith, Lawson and Hernandez
# 1        2.0         18.0                       Lewis LLC
# 2        3.0          8.0                   Medina-Foster
# 3        4.0         15.0                    Butler-Gomez
# 4        5.0          9.0  Campbell, Shaffer and Martinez
# 5        6.0         15.0                    Butler-Gomez
# 6        7.0          7.0                  Berry-Anderson
# 7        8.0         20.0                 Griffin-Leblanc
# 8        9.0         13.0                   Thomas-Nelson
# 9       10.0         13.0                   Thomas-Nelson

# %%
df_all = s4.merge(s1_2_3, how='left', on='customer_id') \
            .merge(s5_6, how='left', on='branch_id')
df_all
# Out:
#       transaction_id  customer_id transaction_date transaction_status  \
# 0                1.0        733.0       2024-05-11         subscribed
# 1                2.0        631.0       2023-05-15             burned
# 2                3.0        309.0       2022-11-13         subscribed
# 3                4.0        695.0       2024-01-26         subscribed
# 4                5.0        288.0       2022-10-12             burned
# ...              ...          ...              ...                ...
# 4995          4996.0        776.0       2024-03-20         subscribed
# 4996          4997.0        583.0       2024-06-27         subscribed
# 4997          4998.0        504.0       2022-11-08             burned
# 4998          4999.0        876.0       2024-05-05             burned
# 4999          5000.0        371.0       2022-08-29         subscribed
#
#      coupon_name  burn_date  branch_id  join_date  city_id  gender_id  \
# 0        uNY-568        NaT        7.0 2023-05-16     15.0        2.0
# 1        kBx-219 2023-06-04        5.0 2022-10-10     14.0        2.0
# 2        PLG-122        NaT        7.0 2022-05-30      2.0        1.0
# 3        Wzf-897        NaT        2.0 2023-11-27     15.0        2.0
# 4        qGb-428 2022-11-20        6.0 2021-09-04     14.0        1.0
# ...          ...        ...        ...        ...      ...        ...
# 4995     OSq-518        NaT        1.0 2022-01-08     12.0        1.0
# 4996     FsJ-607        NaT        2.0 2023-08-03      5.0        2.0
# 4997     WcY-330 2022-12-06        2.0 2022-03-12     10.0        2.0
# 4998     bgx-731 2024-07-29        7.0 2022-11-19      5.0        2.0
# 4999     vYJ-493        NaT        6.0 2022-02-11     16.0        1.0
#
#      gender_name   city_name  merchant_id                   merchant_name
# 0         Female       Aswan          7.0                  Berry-Anderson
# 1         Female    Damietta          9.0  Campbell, Shaffer and Martinez
# 2           Male  Alexandria          7.0                  Berry-Anderson
# 3         Female       Aswan         18.0                       Lewis LLC
# 4           Male    Damietta         15.0                    Butler-Gomez
# ...          ...         ...          ...                             ...
# 4995        Male      Fayyum         11.0     Smith, Lawson and Hernandez
# 4996      Female   Port Said         18.0                       Lewis LLC
# 4997      Female       Asyut         18.0                       Lewis LLC
# 4998      Female   Port Said          7.0                  Berry-Anderson
# 4999        Male       Minya         15.0                    Butler-Gomez
#
# [5000 rows x 14 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## Droping unwanted columns
#
# #### I have made two dataframes each one will be assigned to its most benefit role

# %%
# First
df_only_string = df_all.drop(['city_id', 'gender_id', 'burn_date', 'merchant_id'], axis=1)
df_only_string
# Out:
#       transaction_id  customer_id transaction_date transaction_status  \
# 0                1.0        733.0       2024-05-11         subscribed
# 1                2.0        631.0       2023-05-15             burned
# 2                3.0        309.0       2022-11-13         subscribed
# 3                4.0        695.0       2024-01-26         subscribed
# 4                5.0        288.0       2022-10-12             burned
# ...              ...          ...              ...                ...
# 4995          4996.0        776.0       2024-03-20         subscribed
# 4996          4997.0        583.0       2024-06-27         subscribed
# 4997          4998.0        504.0       2022-11-08             burned
# 4998          4999.0        876.0       2024-05-05             burned
# 4999          5000.0        371.0       2022-08-29         subscribed
#
#      coupon_name  branch_id  join_date gender_name   city_name  \
# 0        uNY-568        7.0 2023-05-16      Female       Aswan
# 1        kBx-219        5.0 2022-10-10      Female    Damietta
# 2        PLG-122        7.0 2022-05-30        Male  Alexandria
# 3        Wzf-897        2.0 2023-11-27      Female       Aswan
# 4        qGb-428        6.0 2021-09-04        Male    Damietta
# ...          ...        ...        ...         ...         ...
# 4995     OSq-518        1.0 2022-01-08        Male      Fayyum
# 4996     FsJ-607        2.0 2023-08-03      Female   Port Said
# 4997     WcY-330        2.0 2022-03-12      Female       Asyut
# 4998     bgx-731        7.0 2022-11-19      Female   Port Said
# 4999     vYJ-493        6.0 2022-02-11        Male       Minya
#
#                        merchant_name
# 0                     Berry-Anderson
# 1     Campbell, Shaffer and Martinez
# 2                     Berry-Anderson
# 3                          Lewis LLC
# 4                       Butler-Gomez
# ...                              ...
# 4995     Smith, Lawson and Hernandez
# 4996                       Lewis LLC
# 4997                       Lewis LLC
# 4998                  Berry-Anderson
# 4999                    Butler-Gomez
#
# [5000 rows x 10 columns]

# %%
# Second
df_only_numbers = df_all.drop(['city_name', 'gender_name', 'burn_date', 'merchant_name'], axis=1)
df_only_numbers
# Out:
#       transaction_id  customer_id transaction_date transaction_status  \
# 0                1.0        733.0       2024-05-11         subscribed
# 1                2.0        631.0       2023-05-15             burned
# 2                3.0        309.0       2022-11-13         subscribed
# 3                4.0        695.0       2024-01-26         subscribed
# 4                5.0        288.0       2022-10-12             burned
# ...              ...          ...              ...                ...
# 4995          4996.0        776.0       2024-03-20         subscribed
# 4996          4997.0        583.0       2024-06-27         subscribed
# 4997          4998.0        504.0       2022-11-08             burned
# 4998          4999.0        876.0       2024-05-05             burned
# 4999          5000.0        371.0       2022-08-29         subscribed
#
#      coupon_name  branch_id  join_date  city_id  gender_id  merchant_id
# 0        uNY-568        7.0 2023-05-16     15.0        2.0          7.0
# 1        kBx-219        5.0 2022-10-10     14.0        2.0          9.0
# 2        PLG-122        7.0 2022-05-30      2.0        1.0          7.0
# 3        Wzf-897        2.0 2023-11-27     15.0        2.0         18.0
# 4        qGb-428        6.0 2021-09-04     14.0        1.0         15.0
# ...          ...        ...        ...      ...        ...          ...
# 4995     OSq-518        1.0 2022-01-08     12.0        1.0         11.0
# 4996     FsJ-607        2.0 2023-08-03      5.0        2.0         18.0
# 4997     WcY-330        2.0 2022-03-12     10.0        2.0         18.0
# 4998     bgx-731        7.0 2022-11-19      5.0        2.0          7.0
# 4999     vYJ-493        6.0 2022-02-11     16.0        1.0         15.0
#
# [5000 rows x 10 columns]

# %%
df_only_numbers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   transaction_id      5000 non-null   float64
#  1   customer_id         5000 non-null   float64
#  2   transaction_date    5000 non-null   datetime64[ns]
#  3   transaction_status  5000 non-null   object
#  4   coupon_name         5000 non-null   object
#  5   branch_id           5000 non-null   float64
#  6   join_date           5000 non-null   datetime64[ns]
#  7   city_id             5000 non-null   float64
#  8   gender_id           5000 non-null   float64
#  9   merchant_id         5000 non-null   float64
# dtypes: datetime64[ns](2), float64(6), object(2)
# memory usage: 429.7+ KB

# %%
df_only_numbers.isna().sum()
# Out:
# transaction_id        0
# customer_id           0
# transaction_date      0
# transaction_status    0
# coupon_name           0
# branch_id             0
# join_date             0
# city_id               0
# gender_id             0
# merchant_id           0
# dtype: int64

# %%
# Get the number of unique values for each column
df_only_numbers.nunique()
# Out:
# transaction_id        5000
# customer_id            989
# transaction_date       885
# transaction_status       2
# coupon_name           5000
# branch_id               10
# join_date              648
# city_id                 20
# gender_id                2
# merchant_id              8
# dtype: int64

# %%
# Checking for duplicated rows in the dataset
df_only_numbers.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Encoding the Dependent Variable

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_only_numbers["transaction_status"] = le.fit_transform(df_only_numbers["transaction_status"])
df_only_numbers["coupon_id"] = le.fit_transform(df_only_numbers["coupon_name"])
df_only_numbers.drop(['coupon_name'], axis=1, inplace=True)

# %%
df_only_numbers
# Out:
#       transaction_id  customer_id transaction_date  transaction_status  \
# 0                1.0        733.0       2024-05-11                   1
# 1                2.0        631.0       2023-05-15                   0
# 2                3.0        309.0       2022-11-13                   1
# 3                4.0        695.0       2024-01-26                   1
# 4                5.0        288.0       2022-10-12                   0
# ...              ...          ...              ...                 ...
# 4995          4996.0        776.0       2024-03-20                   1
# 4996          4997.0        583.0       2024-06-27                   1
# 4997          4998.0        504.0       2022-11-08                   0
# 4998          4999.0        876.0       2024-05-05                   0
# 4999          5000.0        371.0       2022-08-29                   1
#
#       branch_id  join_date  city_id  gender_id  merchant_id  coupon_id
# 0           7.0 2023-05-16     15.0        2.0          7.0       4474
# 1           5.0 2022-10-10     14.0        2.0          9.0       3447
# 2           7.0 2022-05-30      2.0        1.0          7.0       1458
# 3           2.0 2023-11-27     15.0        2.0         18.0       2195
# 4           6.0 2021-09-04     14.0        1.0         15.0       4050
# ...         ...        ...      ...        ...          ...        ...
# 4995        1.0 2022-01-08     12.0        1.0         11.0       1371
# 4996        2.0 2023-08-03      5.0        2.0         18.0        595
# 4997        2.0 2022-03-12     10.0        2.0         18.0       2161
# 4998        7.0 2022-11-19      5.0        2.0          7.0       2632
# 4999        6.0 2022-02-11     16.0        1.0         15.0       4582
#
# [5000 rows x 10 columns]

# %%
# Convert dates to datetime format
df_only_numbers['transaction_date'] = pd.to_datetime(df_only_numbers['transaction_date'])
df_only_numbers['join_date'] = pd.to_datetime(df_only_numbers['join_date'])

# %%
# Visualization 1: Customer Demographics by Gender and City
plt.figure(figsize=(25, 8))
sns.countplot(x='city_name', hue='gender_name', data=df_only_string)
plt.title('Customer Demographics: Gender Distribution by City')
plt.xlabel('City Name')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 2: Coupon Usage (Claimed vs Burnt) Over Time
df_only_string['year_month'] = df_only_string['transaction_date'].dt.to_period('M')  # Group by year and month
coupon_status_count = df_only_string.groupby(['year_month', 'transaction_status']).size().unstack(fill_value=0)

coupon_status_count.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Coupon Usage: Claimed vs Burned Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Number of Transactions')
plt.show()

# %%
# Visualization 3: Top-performing Cities/Branches (Highest Coupon Burns)
burned_df = df_only_string[df_only_string['transaction_status'] == 'burned']
city_burns = burned_df.groupby('city_name').size()
branch_burns = burned_df.groupby('branch_id').size()

# Cities with highest burns
plt.figure(figsize=(10, 5))
colors = plt.cm.viridis(np.linspace(0, 1, len(city_burns)))  # Generate colors dynamically
city_burns.plot(kind='bar', color=colors)
plt.title('Top-performing Cities: Highest Coupon Burns')
plt.xlabel('City Name')
plt.ylabel('Number of Successful Burns')
plt.show()


# Branches with highest burns
plt.figure(figsize=(10, 5))
colors = plt.cm.plasma(np.linspace(0, 1, len(branch_burns)))  # Another colormap
branch_burns.plot(kind='bar', color=colors)
plt.title('Top-performing Branches: Highest Coupon Burns')
plt.xlabel('Branch ID')
plt.ylabel('Number of Successful Burns')
plt.show()

# %%
# Visualization 4: Customer Retention and Loyalty (Coupon Usage Frequency Over Time)
coupon_usage_frequency = df_only_string.groupby('customer_id').size()

plt.figure(figsize=(10, 5))
sns.histplot(coupon_usage_frequency, bins=10, kde=True)
plt.title('Customer Retention and Loyalty: Coupon Usage Frequency')
plt.xlabel('Number of Transactions per Customer')
plt.ylabel('Count of Customers')
plt.show()

# %%
# Filter for burnt transactions
burnt_transactions = df_only_string[df_only_string['transaction_status'] == 'burned']

# Group by merchant_id and count the number of burnt transactions
merchant_burnt_counts = burnt_transactions.groupby('merchant_name')['transaction_id'].count().reset_index()

# Rename columns for clarity
merchant_burnt_counts.columns = ['merchant_name', 'burnt_transaction_count']

# Sort merchants by the number of burnt transactions
merchant_burnt_counts = merchant_burnt_counts.sort_values(by='burnt_transaction_count', ascending=False)

# Plot the top merchants with the most burnt transactions
plt.figure(figsize=(12, 6))
sns.barplot(x='merchant_name', y='burnt_transaction_count', data=merchant_burnt_counts.head(10), palette='viridis')
plt.title('Top 10 Merchants with the Most Burnt Transactions', fontsize=16)
plt.xlabel('Merchant Name', fontsize=12)
plt.ylabel('Number of Burnt Transactions', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Descriptive statistics of the dataset with styled background gradient
df_only_numbers.describe().style.background_gradient(cmap = "Purples")
# Out:
# <style type="text/css">
# #T_75fe9_row0_col0, #T_75fe9_row0_col1, #T_75fe9_row0_col2, #T_75fe9_row0_col3, #T_75fe9_row0_col4, #T_75fe9_row0_col5, #T_75fe9_row0_col6, #T_75fe9_row0_col7, #T_75fe9_row7_col0, #T_75fe9_row7_col7 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_75fe9_row1_col0, #T_75fe9_row5_col0 {
#   background-color: #9e9ac8;
#   color: #f1f1f1;
# }
# #T_75fe9_row1_col1, #T_75fe9_row5_col1 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_75fe9_row1_col2, #T_75fe9_row1_col3, #T_75fe9_row1_col4, #T_75fe9_row1_col5, #T_75fe9_row1_col6, #T_75fe9_row2_col2, #T_75fe9_row2_col3, #T_75fe9_row2_col4, #T_75fe9_row2_col5, #T_75fe9_row2_col6, #T_75fe9_row3_col0, #T_75fe9_row3_col1, #T_75fe9_row3_col2, #T_75fe9_row3_col3, #T_75fe9_row3_col4, #T_75fe9_row3_col5, #T_75fe9_row3_col6, #T_75fe9_row3_col7, #T_75fe9_row4_col2, #T_75fe9_row4_col3, #T_75fe9_row4_col4, #T_75fe9_row4_col5, #T_75fe9_row4_col6, #T_75fe9_row5_col2, #T_75fe9_row5_col3, #T_75fe9_row5_col4, #T_75fe9_row5_col5, #T_75fe9_row5_col6, #T_75fe9_row6_col2, #T_75fe9_row6_col3, #T_75fe9_row6_col4, #T_75fe9_row6_col5, #T_75fe9_row6_col6, #T_75fe9_row7_col2, #T_75fe9_row7_col3, #T_75fe9_row7_col4, #T_75fe9_row7_col5, #T_75fe9_row7_col6 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_75fe9_row1_col7, #T_75fe9_row5_col7 {
#   background-color: #9e9bc8;
#   color: #f1f1f1;
# }
# #T_75fe9_row2_col0, #T_75fe9_row2_col7 {
#   background-color: #d1d2e7;
#   color: #000000;
# }
# #T_75fe9_row2_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_75fe9_row4_col0, #T_75fe9_row4_col7 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_75fe9_row4_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_75fe9_row6_col0 {
#   background-color: #6950a3;
#   color: #f1f1f1;
# }
# #T_75fe9_row6_col1 {
#   background-color: #ebe9f3;
#   color: #000000;
# }
# #T_75fe9_row6_col7 {
#   background-color: #6a51a3;
#   color: #f1f1f1;
# }
# #T_75fe9_row7_col1 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# </style>
# <table id="T_75fe9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75fe9_level0_col0" class="col_heading level0 col0" >transaction_id</th>
#       <th id="T_75fe9_level0_col1" class="col_heading level0 col1" >customer_id</th>
#       <th id="T_75fe9_level0_col2" class="col_heading level0 col2" >transaction_status</th>
#       <th id="T_75fe9_level0_col3" class="col_heading level0 col3" >branch_id</th>
#       <th id="T_75fe9_level0_col4" class="col_heading level0 col4" >city_id</th>
#       <th id="T_75fe9_level0_col5" class="col_heading level0 col5" >gender_id</th>
#       <th id="T_75fe9_level0_col6" class="col_heading level0 col6" >merchant_id</th>
#       <th id="T_75fe9_level0_col7" class="col_heading level0 col7" >coupon_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75fe9_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_75fe9_row0_col0" class="data row0 col0" >5000.000000</td>
#       <td id="T_75fe9_row0_col1" class="data row0 col1" >5000.000000</td>
#       <td id="T_75fe9_row0_col2" class="data row0 col2" >5000.000000</td>
#       <td id="T_75fe9_row0_col3" class="data row0 col3" >5000.000000</td>
#       <td id="T_75fe9_row0_col4" class="data row0 col4" >5000.000000</td>
#       <td id="T_75fe9_row0_col5" class="data row0 col5" >5000.000000</td>
#       <td id="T_75fe9_row0_col6" class="data row0 col6" >5000.000000</td>
#       <td id="T_75fe9_row0_col7" class="data row0 col7" >5000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_75fe9_row1_col0" class="data row1 col0" >2500.500000</td>
#       <td id="T_75fe9_row1_col1" class="data row1 col1" >509.551600</td>
#       <td id="T_75fe9_row1_col2" class="data row1 col2" >0.496800</td>
#       <td id="T_75fe9_row1_col3" class="data row1 col3" >5.529800</td>
#       <td id="T_75fe9_row1_col4" class="data row1 col4" >10.091800</td>
#       <td id="T_75fe9_row1_col5" class="data row1 col5" >1.486600</td>
#       <td id="T_75fe9_row1_col6" class="data row1 col6" >12.882600</td>
#       <td id="T_75fe9_row1_col7" class="data row1 col7" >2499.500000</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_75fe9_row2_col0" class="data row2 col0" >1443.520003</td>
#       <td id="T_75fe9_row2_col1" class="data row2 col1" >287.065172</td>
#       <td id="T_75fe9_row2_col2" class="data row2 col2" >0.500040</td>
#       <td id="T_75fe9_row2_col3" class="data row2 col3" >2.895788</td>
#       <td id="T_75fe9_row2_col4" class="data row2 col4" >5.860703</td>
#       <td id="T_75fe9_row2_col5" class="data row2 col5" >0.499870</td>
#       <td id="T_75fe9_row2_col6" class="data row2 col6" >4.000452</td>
#       <td id="T_75fe9_row2_col7" class="data row2 col7" >1443.520003</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_75fe9_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_75fe9_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_75fe9_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_75fe9_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_75fe9_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_75fe9_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_75fe9_row3_col6" class="data row3 col6" >7.000000</td>
#       <td id="T_75fe9_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_75fe9_row4_col0" class="data row4 col0" >1250.750000</td>
#       <td id="T_75fe9_row4_col1" class="data row4 col1" >262.000000</td>
#       <td id="T_75fe9_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_75fe9_row4_col3" class="data row4 col3" >3.000000</td>
#       <td id="T_75fe9_row4_col4" class="data row4 col4" >5.000000</td>
#       <td id="T_75fe9_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_75fe9_row4_col6" class="data row4 col6" >9.000000</td>
#       <td id="T_75fe9_row4_col7" class="data row4 col7" >1249.750000</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_75fe9_row5_col0" class="data row5 col0" >2500.500000</td>
#       <td id="T_75fe9_row5_col1" class="data row5 col1" >514.000000</td>
#       <td id="T_75fe9_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_75fe9_row5_col3" class="data row5 col3" >6.000000</td>
#       <td id="T_75fe9_row5_col4" class="data row5 col4" >10.000000</td>
#       <td id="T_75fe9_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_75fe9_row5_col6" class="data row5 col6" >13.000000</td>
#       <td id="T_75fe9_row5_col7" class="data row5 col7" >2499.500000</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_75fe9_row6_col0" class="data row6 col0" >3750.250000</td>
#       <td id="T_75fe9_row6_col1" class="data row6 col1" >758.000000</td>
#       <td id="T_75fe9_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_75fe9_row6_col3" class="data row6 col3" >8.000000</td>
#       <td id="T_75fe9_row6_col4" class="data row6 col4" >15.000000</td>
#       <td id="T_75fe9_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_75fe9_row6_col6" class="data row6 col6" >15.000000</td>
#       <td id="T_75fe9_row6_col7" class="data row6 col7" >3749.250000</td>
#     </tr>
#     <tr>
#       <th id="T_75fe9_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_75fe9_row7_col0" class="data row7 col0" >5000.000000</td>
#       <td id="T_75fe9_row7_col1" class="data row7 col1" >1000.000000</td>
#       <td id="T_75fe9_row7_col2" class="data row7 col2" >1.000000</td>
#       <td id="T_75fe9_row7_col3" class="data row7 col3" >10.000000</td>
#       <td id="T_75fe9_row7_col4" class="data row7 col4" >20.000000</td>
#       <td id="T_75fe9_row7_col5" class="data row7 col5" >2.000000</td>

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(df_only_numbers.corr(), cmap="viridis",annot=True,linewidths=0.1) 
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.countplot(x='transaction_status', data=df_only_numbers)
# Out:
# <AxesSubplot:xlabel='transaction_status', ylabel='count'>

# %%
# Select relevant features for segmentation
X = df_only_numbers[['gender_id', 'city_id', 'customer_id', 'transaction_id', 'branch_id', 'merchant_id']]

# %%
from sklearn.preprocessing import StandardScaler

# Scale the data 
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ## K-means clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Initialize lists to store metrics
inertia = []
silhouette_scores = []

# Try different numbers of clusters (k)
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    
    # Inertia (within-cluster sum of squares)
    inertia.append(kmeans.inertia_)
    
    # Silhouette score
    silhouette_avg = silhouette_score(X, kmeans.labels_)
    silhouette_scores.append(silhouette_avg)

# Plot the inertia and silhouette score to determine the optimal k
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

# Plot inertia
plt.subplot(1, 2, 1)
plt.plot(range(2, 11), inertia, marker='o')
plt.title('Inertia for Different Cluster Numbers')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')

# Plot silhouette score
plt.subplot(1, 2, 2)
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Cluster Numbers')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')

plt.show()

# %%
# Fit K-Means with the optimal number of clusters 
optimal_k = 6
kmeans_final = KMeans(n_clusters=optimal_k, random_state=42)
df_only_numbers['cluster'] = kmeans_final.fit_predict(X)

# Calculate final silhouette score
silhouette_avg = silhouette_score(X, df_only_numbers['cluster'])
print(f"Silhouette Score for {optimal_k} clusters: {silhouette_avg}")
# Out:
# Silhouette Score for 6 clusters: 0.1643977830253382

# %%
# Analyze the clusters
for cluster_num in range(optimal_k):
    print(f"\nCluster {cluster_num} Analysis:")
    cluster_data = df_only_numbers[df_only_numbers['cluster'] == cluster_num]
    
    # Summary statistics for each cluster
    print(cluster_data[['customer_id', 'transaction_id', 'branch_id', 'city_id', 'gender_id']].describe())
    
    # Percentage of burned vs subscribed coupons in this cluster
    coupon_status_dist = cluster_data['transaction_status'].value_counts(normalize=True) * 100
    print(f"Coupon Status Distribution for Cluster {cluster_num}:\n{coupon_status_dist}")
# Out:
# Cluster 0 Analysis:
#        customer_id  transaction_id   branch_id     city_id  gender_id
# count   766.000000      766.000000  766.000000  766.000000      766.0
# mean    499.941253     3719.960836    6.280679   10.511749        1.0
# std     287.944108      746.684167    2.796509    5.968041        0.0
# min       1.000000     2166.000000    2.000000    1.000000        1.0
# 25%     254.250000     3102.250000    4.000000    5.000000        1.0
# 50%     499.000000     3733.500000    6.000000   11.000000        1.0
# 75%     753.000000     4353.000000    9.000000   16.000000        1.0
# max     996.000000     5000.000000   10.000000   20.000000        1.0
# Coupon Status Distribution for Cluster 0:
# 0    51.305483
# 1    48.694517
# Name: transaction_status, dtype: float64
#
# Cluster 1 Analysis:
#        customer_id  transaction_id   branch_id     city_id  gender_id
# count   739.000000      739.000000  739.000000  739.000000      739.0
# mean    521.981055     2493.533153    6.879567   15.056834        2.0
# std     287.997158     1476.707695    2.802022    3.006680        0.0
# min       2.000000        4.000000    2.000000   10.000000        2.0
# 25%     261.000000     1174.500000    4.000000   12.000000        2.0
# 50%     525.000000     2473.000000    8.000000   15.000000        2.0
# 75%     763.000000     3838.000000    9.000000   17.000000        2.0
# max     998.000000     4993.000000   10.000000   20.000000        2.0
# Coupon Status Distribution for Cluster 1:
# 1    50.067659
# 0    49.932341
# Name: transaction_status, dtype: float64
#
# Cluster 2 Analysis:
#        customer_id  transaction_id   branch_id     city_id  gender_id
# count   762.000000      762.000000  762.000000  762.000000      762.0
# mean    497.948819     1212.279528    6.624672    9.724409        1.0
# std     282.837126      722.717642    2.727351    5.825104        0.0
# min       1.000000        5.000000    2.000000    1.000000        1.0
# 25%     268.000000      568.250000    4.000000    5.000000        1.0
# 50%     499.500000     1162.500000    8.000000    9.000000        1.0
# 75%     747.500000     1832.750000    9.000000   15.000000        1.0
# max     999.000000     2787.000000   10.000000   20.000000        1.0
# Coupon Status Distribution for Cluster 2:
# 1    52.362205
# 0    47.637795
# Name: transaction_status, dtype: float64
#
# Cluster 3 Analysis:
#        customer_id  transaction_id   branch_id     city_id  gender_id
# count   960.000000      960.000000  960.000000  960.000000      960.0
# mean    528.126042     2549.102083    3.960417   10.039583        2.0
# std     289.518553     1430.021509    2.260993    5.854198        0.0
# min       2.000000        1.000000    1.000000    1.000000        2.0
# 25%     268.750000     1343.750000    1.000000    5.000000        2.0
# 50%     536.000000     2562.000000    3.000000   10.000000        2.0
# 75%     782.250000     3771.000000    5.000000   15.000000        2.0
# max    1000.000000     4999.000000    7.000000   20.000000        2.0
# Coupon Status Distribution for Cluster 3:
# 0    50.208333
# 1    49.791667
# Name: transaction_status, dtype: float64
#
# Cluster 4 Analysis:
#        customer_id  transaction_id    branch_id      city_id  gender_id
# count  1039.000000     1039.000000  1039.000000  1039.000000     1039.0
# mean    501.529355     2463.725698     3.948989    10.345525        1.0
# std     280.762832     1423.831985     2.254581     5.684458        0.0
# min       1.000000        3.000000     1.000000     1.000000        1.0
# 25%     269.000000     1251.500000     1.000000     5.000000        1.0
# 50%     509.000000     2477.000000     3.000000    10.000000        1.0
# 75%     741.500000     3709.500000     5.000000    15.000000        1.0
# max     999.000000     4996.000000     7.000000    20.000000        1.0
# Coupon Status Distribution for Cluster 4:
# 0    50.914341
# 1    49.085659
# Name: transaction_status, dtype: float64
#
# Cluster 5 Analysis:
#        customer_id  transaction_id   branch_id     city_id  gender_id
# count   734.000000      734.000000  734.000000  734.000000      734.0
# mean    506.174387     2560.739782    6.540872    4.745232        2.0
# std     294.403375     1434.258657    2.837162    2.872782        0.0
# min      10.000000       20.000000    2.000000    1.000000        2.0
# 25%     247.000000     1322.500000    4.000000    2.000000        2.0
# 50%     513.500000     2593.500000    6.000000    4.000000        2.0
# 75%     779.750000     3774.750000    9.000000    7.000000        2.0
# max    1000.000000     4998.000000   10.000000   11.000000        2.0
# Coupon Status Distribution for Cluster 5:
# 0    51.771117
# 1    48.228883
# Name: transaction_status, dtype: float64

# %%
from sklearn.decomposition import PCA

# Fit K-Means model with the optimal number of clusters
optimal_k = 6
kmeans_final = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans_final.fit_predict(X) 

# Apply PCA for 2D visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X)  # Use the scaled X

# Visualize the clusters
plt.figure(figsize=(10, 7))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=clusters, cmap='viridis', s=50)

# Mark the cluster centroids
centroids = pca.transform(kmeans_final.cluster_centers_)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.75, marker='X')

# Titles and labels
plt.title('Customer Segmentation using K-Means and PCA')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Fit K-Means model with the optimal number of clusters
optimal_k = 6
kmeans_final = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans_final.fit_predict(X) 

# Apply PCA for 3D visualization
pca = PCA(n_components=3)
pca_result = pca.fit_transform(X) 

# 3D Visualization
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(pca_result[:, 0], pca_result[:, 1], pca_result[:, 2], c=clusters, cmap='viridis', s=50)

# Mark the cluster centroids in 3D
centroids = pca.transform(kmeans_final.cluster_centers_)
ax.scatter(centroids[:, 0], centroids[:, 1], centroids[:, 2], c='red', s=200, alpha=0.75, marker='X')

# Titles and labels
ax.set_title('Customer Segmentation using K-Means and PCA (3D)')
ax.set_xlabel('PCA Component 1')
ax.set_ylabel('PCA Component 2')
ax.set_zlabel('PCA Component 3')

# Show plot
plt.show()

# %% [markdown]
# ## DBSCAN (Density-Based Spatial Clustering of Applications with Noise)

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.9, min_samples=8)
df_only_numbers['dbscan_cluster'] = dbscan.fit_predict(X)

# Calculate silhouette score
silhouette_avg = silhouette_score(X, df_only_numbers['dbscan_cluster'])
print(f"Silhouette Score for DBSCAN: {silhouette_avg}")
# Out:
# Silhouette Score for DBSCAN: 0.14787077726678208

# %% [markdown]
# ## Agglomerative (Hierarchical) Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

agglomerative = AgglomerativeClustering(n_clusters=4, linkage='average')
df_only_numbers['agg_cluster'] = agglomerative.fit_predict(X)

# Calculate silhouette score
silhouette_avg = silhouette_score(X, df_only_numbers['agg_cluster'])
print(f"Silhouette Score for Agglomerative Clustering: {silhouette_avg}")
# Out:
# Silhouette Score for Agglomerative Clustering: 0.15191168735952443

# %%
# Create a figure with subplots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Perform PCA to reduce dimensionality to 2 components for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# DBSCAN clustering visualization
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=df_only_numbers['dbscan_cluster'], palette='viridis', ax=ax[0])
ax[0].set_title('DBSCAN Clustering')
ax[0].set_xlabel('PCA Component 1')
ax[0].set_ylabel('PCA Component 2')

# Agglomerative Clustering visualization
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=df_only_numbers['agg_cluster'], palette='coolwarm', ax=ax[1])
ax[1].set_title('Agglomerative Clustering')
ax[1].set_xlabel('PCA Component 1')
ax[1].set_ylabel('PCA Component 2')

plt.tight_layout()
plt.show()

# %%
from sklearn.manifold import TSNE

# Perform t-SNE to reduce dimensionality to 2 components for visualization
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Create a figure with subplots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# DBSCAN clustering visualization
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=df_only_numbers['dbscan_cluster'], palette='viridis', ax=ax[0])
ax[0].set_title('DBSCAN Clustering with t-SNE')
ax[0].set_xlabel('t-SNE Component 1')
ax[0].set_ylabel('t-SNE Component 2')

# Agglomerative Clustering visualization
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=df_only_numbers['agg_cluster'], palette='coolwarm', ax=ax[1])
ax[1].set_title('Agglomerative Clustering with t-SNE')
ax[1].set_xlabel('t-SNE Component 1')
ax[1].set_ylabel('t-SNE Component 2')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
